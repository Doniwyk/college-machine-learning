# %% [markdown]
# # Practicum 3

# %%
# %pip install minisom
# Out:
# Collecting minisom
#   Downloading MiniSom-2.3.3.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: minisom
#   Building wheel for minisom (setup.py) ... done
#   Created wheel for minisom: filename=MiniSom-2.3.3-py3-none-any.whl size=11705 sha256=c127d5093ade647d82ed2be4d151fb597c29cfb551796ef75101e21f9bc5d266
#   Stored in directory: /home/doni/.cache/pip/wheels/ec/7e/00/ac334ebb21e9016a73bef195e9732606217c6894f96bd51e6f
# Successfully built minisom
# Installing collected packages: minisom
# Successfully installed minisom-2.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from minisom import MiniSom
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
iris = datasets.load_iris()
data = iris.data

# %% [markdown]
# ## normalization data

# %%
data = data / data.max(axis=0)

# %% [markdown]
# ## Define map size

# %%
# Inisialisasi SOM
map_size = (10, 10)
som = MiniSom(map_size[0], map_size[1], data.shape[1], sigma=0.5, learning_rate=0.5)

# %% [markdown]
# ## Inisialization SOM weight

# %%
som.random_weights_init(data)

# %% [markdown]
# ## Train SOM with `train_random`

# %%
num_epochs = 100
som.train_random(data, num_epochs)

# %% [markdown]
# ## Print map with color and mark winner for each sample

# %%
plt.figure(figsize=(8, 8))
for i, x in enumerate(data):
    w = som.winner(x) 
    plt.text(w[0]+.5, w[1]+.5, str(i+1), color='k', fontdict={'weight': 'bold', 'size': 11})
plt.pcolor(som.distance_map().T, cmap='bone_r', alpha=.2)
plt.colorbar()

plt.show()
